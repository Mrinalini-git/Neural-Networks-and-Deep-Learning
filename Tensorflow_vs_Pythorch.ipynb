# %%
import numpy as np

# 2. Define the number of samples and features
n_samples = 1000
n_features = 10

# 3. Generate random input features X
X = np.random.rand(n_samples, n_features)
print(f"Shape of X: {X.shape}")

# 4. Create random 'true' weights and a bias term
true_weights = np.random.rand(n_features)
bias = np.random.rand(1)

# 5. Generate target labels y with noise
y = np.dot(X, true_weights) + bias + 0.1 * np.random.randn(n_samples)
print(f"Shape of y: {y.shape}")
# Out:
# Shape of X: (1000, 10)
# Shape of y: (1000,)

# %%
import torch.nn as nn
import torch.optim as optim

# 1. Convert numpy arrays to PyTorch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

print(f"X_tensor shape: {X_tensor.shape}")
print(f"y_tensor shape: {y_tensor.shape}")

# 2. Instantiate the loss function
criterion = nn.MSELoss()
print("Loss function (criterion) initialized as MSELoss.")

# 3. Instantiate the optimizer
learning_rate = 0.01
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
print(f"Optimizer initialized as Adam with learning rate: {learning_rate}")
# Out:
# X_tensor shape: torch.Size([1000, 10])
# y_tensor shape: torch.Size([1000, 1])
# Loss function (criterion) initialized as MSELoss.
# Optimizer initialized as Adam with learning rate: 0.01

# %%
num_epochs = 100
pytorch_losses = []

print("Starting PyTorch model training...")
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_tensor)
    loss = criterion(outputs, y_tensor)

    # Store loss
    pytorch_losses.append(loss.item())

    # Backward and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

final_pytorch_loss = pytorch_losses[-1]
print(f"\nFinal PyTorch Training Loss: {final_pytorch_loss:.4f}")
# Out:
# Starting PyTorch model training...
# Epoch [10/100], Loss: 10.9591
# Epoch [20/100], Loss: 5.0761
# Epoch [30/100], Loss: 0.7773
# Epoch [40/100], Loss: 0.3669
# Epoch [50/100], Loss: 0.3500
# Epoch [60/100], Loss: 0.1541
# Epoch [70/100], Loss: 0.1724
# Epoch [80/100], Loss: 0.1361
# Epoch [90/100], Loss: 0.1303
# Epoch [100/100], Loss: 0.1194
#
# Final PyTorch Training Loss: 0.1194
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:634: UserWarning: Using a target size (torch.Size([1000, 1])) that is different to the input size (torch.Size([1000, 2])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
num_epochs = 100
pytorch_losses = []

print("Starting PyTorch model training...")
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_tensor)
    loss = criterion(outputs, y_tensor)

    # Store loss
    pytorch_losses.append(loss.item())

    # Backward and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

final_pytorch_loss = pytorch_losses[-1]
print(f"\nFinal PyTorch Training Loss: {final_pytorch_loss:.4f}")
# Out:
# Starting PyTorch model training...
# Epoch [10/100], Loss: 0.1118
# Epoch [20/100], Loss: 0.1039
# Epoch [30/100], Loss: 0.0968
# Epoch [40/100], Loss: 0.0898
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:634: UserWarning: Using a target size (torch.Size([1000, 1])) that is different to the input size (torch.Size([1000, 2])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [50/100], Loss: 0.0832
# Epoch [60/100], Loss: 0.0770
# Epoch [70/100], Loss: 0.0712
# Epoch [80/100], Loss: 0.0657
# Epoch [90/100], Loss: 0.0606
# Epoch [100/100], Loss: 0.0558
#
# Final PyTorch Training Loss: 0.0558

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define the FeedForward Neural Network
class SimpleFeedForwardNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(SimpleFeedForwardNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)  # First hidden layer
        self.relu = nn.ReLU()                          # Activation function
        self.fc2 = nn.Linear(hidden_size, output_size) # Output layer

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# Example Usage:
# Define hyperparameters
input_size = 10
hidden_size = 5
output_size = 1 # Corrected: Changed from 2 to 1 to match the single regression target
batch_size = 1

# Instantiate the model
model = SimpleFeedForwardNet(input_size, hidden_size, output_size)
print("Model Architecture:")
print(model)

# Create some dummy input data
dummy_input = torch.randn(batch_size, input_size) # Batch size of 1, input_size features
print(f"\nDummy Input Shape: {dummy_input.shape}")

# Perform a forward pass
output = model(dummy_input)
print(f"Output from the network: {output}")
print(f"Output Shape: {output.shape}")
# Out:
# Model Architecture:
# SimpleFeedForwardNet(
#   (fc1): Linear(in_features=10, out_features=5, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=5, out_features=1, bias=True)
# )
#
# Dummy Input Shape: torch.Size([1, 10])
# Output from the network: tensor([[-0.3110]], grad_fn=<AddmmBackward0>)
# Output Shape: torch.Size([1, 1])

# %%
num_epochs = 100
pytorch_losses = []

print("Starting PyTorch model training...")
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_tensor)
    loss = criterion(outputs, y_tensor)

    # Store loss
    pytorch_losses.append(loss.item())

    # Backward and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

final_pytorch_loss = pytorch_losses[-1]
print(f"\nFinal PyTorch Training Loss: {final_pytorch_loss:.4f}")
# Out:
# Starting PyTorch model training...
# Epoch [10/100], Loss: 16.1666
# Epoch [20/100], Loss: 16.1666
# Epoch [30/100], Loss: 16.1666
# Epoch [40/100], Loss: 16.1666
# Epoch [50/100], Loss: 16.1666
# Epoch [60/100], Loss: 16.1666
# Epoch [70/100], Loss: 16.1666
# Epoch [80/100], Loss: 16.1666
# Epoch [90/100], Loss: 16.1666
# Epoch [100/100], Loss: 16.1666
#
# Final PyTorch Training Loss: 16.1666

# %%
import torch.nn as nn
import torch.optim as optim

# 1. Convert numpy arrays to PyTorch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

print(f"X_tensor shape: {X_tensor.shape}")
print(f"y_tensor shape: {y_tensor.shape}")

# 2. Instantiate the loss function
criterion = nn.MSELoss()
print("Loss function (criterion) initialized as MSELoss.")

# 3. Instantiate the optimizer (RE-INITIALIZED)
learning_rate = 0.01
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
print(f"Optimizer re-initialized as Adam with learning rate: {learning_rate}")
# Out:
# X_tensor shape: torch.Size([1000, 10])
# y_tensor shape: torch.Size([1000, 1])
# Loss function (criterion) initialized as MSELoss.
# Optimizer re-initialized as Adam with learning rate: 0.01

# %%
num_epochs = 100
pytorch_losses = []

print("Starting PyTorch model training...")
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(X_tensor)
    loss = criterion(outputs, y_tensor)

    # Store loss
    pytorch_losses.append(loss.item())

    # Backward and optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

final_pytorch_loss = pytorch_losses[-1]
print(f"\nFinal PyTorch Training Loss: {final_pytorch_loss:.4f}")
# Out:
# Starting PyTorch model training...
# Epoch [10/100], Loss: 12.7792
# Epoch [20/100], Loss: 7.1834
# Epoch [30/100], Loss: 1.7310
# Epoch [40/100], Loss: 0.0768
# Epoch [50/100], Loss: 0.3785
# Epoch [60/100], Loss: 0.0604
# Epoch [70/100], Loss: 0.0795
# Epoch [80/100], Loss: 0.0530
# Epoch [90/100], Loss: 0.0459
# Epoch [100/100], Loss: 0.0426
#
# Final PyTorch Training Loss: 0.0426

# %%
import tensorflow as tf

# 1. Convert numpy arrays to TensorFlow tensors
X_tf = tf.constant(X, dtype=tf.float32)
y_tf = tf.constant(y, dtype=tf.float32) # y is already (1000,) from numpy, will be reshaped to (1000,1) implicitly by Keras loss if input is (1000,1).

# Reshape y_tf to (-1, 1) to match the model's output shape
y_tf = tf.reshape(y_tf, (-1, 1))

print(f"X_tf shape: {X_tf.shape}")
print(f"y_tf shape: {y_tf.shape}")

# 2. Compile the TensorFlow model
# 3. Specify optimizer and loss
model_tf.compile(optimizer='adam', loss='mse', metrics=['mse'])
print("TensorFlow model compiled with Adam optimizer and MSE loss.")
# Out:
# X_tf shape: (1000, 10)
# y_tf shape: (1000, 1)
# TensorFlow model compiled with Adam optimizer and MSE loss.

# %%
num_epochs = 100

print("Starting TensorFlow model training...")
history_tf = model_tf.fit(X_tf, y_tf, epochs=num_epochs, verbose=0) # verbose=0 to suppress per-epoch output

# Extract the final loss from the history object
final_tensorflow_loss = history_tf.history['loss'][-1]
print(f"\nFinal TensorFlow Training Loss: {final_tensorflow_loss:.4f}")
# Out:
# Starting TensorFlow model training...
#
# Final TensorFlow Training Loss: 0.0141

# %% [markdown]
# Tensorflow has demonstrated superior performance.
